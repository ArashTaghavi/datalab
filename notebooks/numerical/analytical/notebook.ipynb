# %%
import pandas as pd
from datalab.numerical import NumericalContinuousAnalytical

# %%
df = pd.DataFrame({
    "age": [
        28, 31, 35, 29, 33, 37, 30, 32, 34, 36,
        27, 31, 29, 35, 33, 30, 32, 38, 34, 31,
        29, 36, 28, 33, 35, 30, 32, 34, 37, 31,
        29, 35, 33, 30, 32, 36, 34, 28, 31, 33,
        35, 30, 32, 34, 37, 31, 29,
        
        # Outliers
        5, 72, 80
    ]
})
run = NumericalContinuousAnalytical(column=df['age'])

# %%
run.histogram_plot()

# %%
run.box_plot()

# %%
run.violin_plot()

# %%
run.cdf_plot()

# %%
run.density_plot()

# %%
run.feature_type_plot()

# %%
run.frequency_plot()

# %%
run.missing_value_plot()

# %%
run.transformation_plot()

# %%
run.binning_plot()
