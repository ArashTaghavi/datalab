# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import OutlierDistributionDataset

# %%
run = NumericalContinuous(OutlierDistributionDataset())

# %%
run.distribution()
# Out:
#                Dataset         Min         Max        Mean       Std  \
# 0          No Outliers  140.812697  195.430829  169.768868  7.913737
# 1         Few Outliers  140.812697  225.000000  169.895262  8.300933
# 2        Many Outliers  140.812697  222.000000  170.093511  8.812199
# 3   Symmetric Outliers  135.000000  205.000000  169.708511  8.291847
# 4  One Extreme Outlier  140.812697  300.000000  169.892278  8.918662
#
#    Percentage Within ±5 of Mean
# 0                          48.9
# 1                          48.5
# 2                          48.6
# 3                          48.6
# 4                          48.7

# %%
run.box_plot()

# %%
run.violin_plot()

# %%
run.cdf_plot()

# %%
run.qq_plot()

# %%
run.mean_std_plot()
