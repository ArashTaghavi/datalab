# %%
from datalab.numerical import NumericalContinuous

# %%
run = NumericalContinuous()

# %%
run.distribution()
# Out:
#            Dataset  Min  Max     Mean        Std  Percentage Within ±5 of Mean
# 0     Low Variance  159  179  169.411   2.984457                          90.1
# 1  Medium Variance  139  199  168.688  10.148875                          39.0
# 2    High Variance  108  231  170.174  20.334188                          20.9
# 3     Shifted Mean  157  215  184.483   9.771653                          39.3

# %%
# run.box_plot()

# %%
# run.violin_plot()

# %%
# run.cdf_plot()

# %%
# run.qq_plot()

# %%
# run.mean_std_plot()
