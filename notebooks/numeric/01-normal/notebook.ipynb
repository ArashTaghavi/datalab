# %%
from datalab.numerical import NumericalContinuous

# %%
run = NumericalContinuous()

# %%
# run.distribution()

# %%
# run.box_plot()

# %%
# run.violin_plot()

# %%
# run.cdf_plot()

# %%
# run.qq_plot()

# %%
run.mean_std_plot()
# Out:
#            Dataset     Mean        Std  Mean - Std  Mean + Std
# 0     Low Variance  169.411   2.984457  166.426543  172.395457
# 1  Medium Variance  168.688  10.148875  158.539125  178.836875
# 2    High Variance  170.174  20.334188  149.839812  190.508188
# 3     Shifted Mean  184.483   9.771653  174.711347  194.254653
