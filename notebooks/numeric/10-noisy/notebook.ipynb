# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import NoisyDistributionDataset

# %%
run = NumericalContinuous(NoisyDistributionDataset())

# %%
run.distribution()
# Out:
#           Dataset         Min         Max        Mean        Std  \
# 0        No Noise  140.812697  195.430829  169.768868   7.913737
# 1      Mild Noise  142.813660  195.463525  169.687489   7.970556
# 2  Moderate Noise  143.675790  198.347359  169.903672   9.006391
# 3    Strong Noise  130.795125  209.088467  169.757195  11.162303
# 4   Extreme Noise  110.229667  223.749005  169.427148  17.774842
#
#    Percentage Within ±5 of Mean
# 0                          48.9
# 1                          49.4
# 2                          44.0
# 3                          35.6
# 4                          23.6

# %%
run.box_plot()
# Out:
#           Dataset         Min          Q1      Median        Mean          Q3  \
# 0        No Noise  140.812697  164.429497  170.049423  169.768868  174.719094
# 1      Mild Noise  142.813660  164.408743  169.902225  169.687489  174.565906
# 2  Moderate Noise  143.675790  163.931188  170.076397  169.903672  175.524852
# 3    Strong Noise  130.795125  162.231698  169.703804  169.757195  176.915811
# 4   Extreme Noise  110.229667  157.619208  169.604558  169.427148  180.634555
#
#           Max        IQR  Box Width
# 0  195.430829  10.289597  10.289597
# 1  195.463525  10.157164  10.157164
# 2  198.347359  11.593663  11.593663
# 3  209.088467  14.684113  14.684113
# 4  223.749005  23.015347  23.015347

# %%
run.violin_plot()
# Out:
#           Dataset         Min         Max       Range        Std          Q1  \
# 0        No Noise  140.812697  195.430829   54.618132   7.909779  164.429497
# 1      Mild Noise  142.813660  195.463525   52.649864   7.966570  164.408743
# 2  Moderate Noise  143.675790  198.347359   54.671569   9.001886  163.931188
# 3    Strong Noise  130.795125  209.088467   78.293343  11.156720  162.231698
# 4   Extreme Noise  110.229667  223.749005  113.519338  17.765952  157.619208
#
#            Q3        IQR  Peak Density Value  Peak Densiسty
# 0  174.719094  10.289597          171.429468       0.052158
# 1  174.565906  10.157164          171.062236       0.052335
# 2  175.524852  11.593663          170.874759       0.045662
# 3  176.915811  14.684113          169.118893       0.034591
# 4  180.634555  23.015347          170.341508       0.023007

# %%
run.cdf_plot()
# Out:
#           Dataset         Min         Max       Range         P10          Q1  \
# 0        No Noise  140.812697  195.430829   54.618132  159.735092  164.429497
# 1      Mild Noise  142.813660  195.463525   52.649864  159.594203  164.408743
# 2  Moderate Noise  143.675790  198.347359   54.671569  158.516995  163.931188
# 3    Strong Noise  130.795125  209.088467   78.293343  155.708957  162.231698
# 4   Extreme Noise  110.229667  223.749005  113.519338  147.077043  157.619208
#
#        Median          Q3         P90  P10-P90 Range
# 0  170.049423  174.719094  180.031978      20.296885
# 1  169.902225  174.565906  180.453007      20.858804
# 2  170.076397  175.524852  181.718708      23.201713
# 3  169.703804  176.915811  184.237208      28.528250
# 4  169.604558  180.634555  192.012732      44.935689

# %%
run.qq_plot()
# Out:
#           Dataset  Correlation        R²      RMSE  Max Absolute Deviation  \
# 0        No Noise     0.999381  0.998763  0.278175                2.927999
# 1      Mild Noise     0.999240  0.998480  0.310600                1.317515
# 2  Moderate Noise     0.999236  0.998473  0.351770                3.389709
# 3    Strong Noise     0.999449  0.998897  0.370466                3.182226
# 4   Extreme Noise     0.998922  0.997845  0.824660                4.718669
#
#          Mean        Std
# 0  169.768868   7.909779
# 1  169.687489   7.966570
# 2  169.903672   9.001886
# 3  169.757195  11.156720
# 4  169.427148  17.765952

# %%
run.mean_std_plot()
# Out:
#           Dataset        Mean        Std  Mean - Std  Mean + Std
# 0        No Noise  169.768868   7.913737  161.855131  177.682604
# 1      Mild Noise  169.687489   7.970556  161.716933  177.658045
# 2  Moderate Noise  169.903672   9.006391  160.897282  178.910063
# 3    Strong Noise  169.757195  11.162303  158.594892  180.919498
# 4   Extreme Noise  169.427148  17.774842  151.652306  187.201990
