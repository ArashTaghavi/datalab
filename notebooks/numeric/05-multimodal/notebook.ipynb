# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import MultimodalDistributionDataset

# %%
run = NumericalContinuous(MultimodalDistributionDataset())

# %%
run.distribution()
# Out:
#                 Dataset         Min         Max        Mean        Std  \
# 0              Unimodal  140.812697  195.430829  169.768868   7.913737
# 1    Bimodal - Balanced  140.221906  199.571223  169.593108  15.470219
# 2  Bimodal - Imbalanced  144.681101  205.297656  167.668506  14.030386
# 3              Trimodal  139.002258  201.381178  168.994164  16.374275
# 4     Overlapping Modes  139.102434  197.859785  167.329140  10.769816
#
#    Percentage Within ±5 of Mean
# 0                          48.9
# 1                           2.9
# 2                          22.4
# 3                          26.6
# 4                          32.7

# %%
run.box_plot()
# Out:
#                 Dataset         Min          Q1      Median        Mean  \
# 0              Unimodal  140.812697  164.429497  170.049423  169.768868
# 1    Bimodal - Balanced  140.221906  155.015399  169.403946  169.593108
# 2  Bimodal - Imbalanced  144.681101  158.012137  162.366070  167.668506
# 3              Trimodal  139.002258  152.359210  169.514823  168.994164
# 4     Overlapping Modes  139.102434  159.416644  167.200548  167.329140
#
#            Q3         Max        IQR  Box Width
# 0  174.719094  195.430829  10.289597  10.289597
# 1  184.307234  199.571223  29.291836  29.291836
# 2  174.790978  205.297656  16.778841  16.778841
# 3  185.812063  201.381178  33.452853  33.452853
# 4  175.537996  197.859785  16.121352  16.121352

# %%
run.violin_plot()
# Out:
#                 Dataset         Min         Max      Range        Std  \
# 0              Unimodal  140.812697  195.430829  54.618132   7.909779
# 1    Bimodal - Balanced  140.221906  199.571223  59.349317  15.462482
# 2  Bimodal - Imbalanced  144.681101  205.297656  60.616555  14.023369
# 3              Trimodal  139.002258  201.381178  62.378919  16.366086
# 4     Overlapping Modes  139.102434  197.859785  58.757351  10.764430
#
#            Q1          Q3        IQR  Peak Density Value  Peak Densiسty
# 0  164.429497  174.719094  10.289597          171.429468       0.052158
# 1  155.015399  184.307234  29.291836          184.481407       0.031443
# 2  158.012137  174.790978  16.778841          160.275149       0.049042
# 3  152.359210  185.812063  33.452853          150.179262       0.025020
# 4  159.416644  175.537996  16.121352          163.334694       0.032184

# %%
run.cdf_plot()
# Out:
#                 Dataset         Min         Max      Range         P10  \
# 0              Unimodal  140.812697  195.430829  54.618132  159.735092
# 1    Bimodal - Balanced  140.221906  199.571223  59.349317  150.703152
# 2  Bimodal - Imbalanced  144.681101  205.297656  60.616555  154.778608
# 3              Trimodal  139.002258  201.381178  62.378919  147.910977
# 4     Overlapping Modes  139.102434  197.859785  58.757351  153.462922
#
#            Q1      Median          Q3         P90  P10-P90 Range
# 0  164.429497  170.049423  174.719094  180.031978      20.296885
# 1  155.015399  169.403946  184.307234  188.356583      37.653431
# 2  158.012137  162.366070  174.790978  191.496865      36.718257
# 3  152.359210  169.514823  185.812063  191.261977      43.351000
# 4  159.416644  167.200548  175.537996  181.377125      27.914203

# %%
run.qq_plot()
# Out:
#                 Dataset  Correlation        R²      RMSE  \
# 0              Unimodal     0.999381  0.998763  0.278175
# 1    Bimodal - Balanced     0.944224  0.891560  5.091835
# 2  Bimodal - Imbalanced     0.920995  0.848232  5.463150
# 3              Trimodal     0.965296  0.931796  4.274157
# 4     Overlapping Modes     0.997661  0.995327  0.735842
#
#    Max Absolute Deviation        Mean        Std
# 0                2.927999  169.768868   7.909779
# 1               18.701938  169.593108  15.462482
# 2               19.538897  167.668506  14.023369
# 3               22.026047  168.994164  16.366086
# 4                7.134087  167.329140  10.764430

# %%
run.mean_std_plot()
# Out:
#                 Dataset        Mean        Std  Mean - Std  Mean + Std
# 0              Unimodal  169.768868   7.913737  161.855131  177.682604
# 1    Bimodal - Balanced  169.593108  15.470219  154.122890  185.063327
# 2  Bimodal - Imbalanced  167.668506  14.030386  153.638120  181.698892
# 3              Trimodal  168.994164  16.374275  152.619889  185.368439
# 4     Overlapping Modes  167.329140  10.769816  156.559324  178.098956
