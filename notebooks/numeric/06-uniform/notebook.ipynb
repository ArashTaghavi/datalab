# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import UniformDistributionDataset

# %%
run = NumericalContinuous(UniformDistributionDataset())

# %%
run.distribution()
# Out:
#              Dataset         Min         Max        Mean        Std  \
# 0     Narrow Uniform  160.024661  179.982095  169.943557   5.831714
# 1   Moderate Uniform  150.020750  189.976876  170.339824  11.573706
# 2       Wide Uniform  130.079200  209.981227  169.429876  23.165716
# 3  Very Wide Uniform  100.089923  239.917250  169.100110  40.638659
# 4    Shifted Uniform  180.037044  219.988594  199.437709  11.274433
#
#    Percentage Within ±5 of Mean
# 0                          48.1
# 1                          25.8
# 2                          13.1
# 3                           7.0
# 4                          24.8

# %%
run.box_plot()
# Out:
#              Dataset         Min          Q1      Median        Mean  \
# 0     Narrow Uniform  160.024661  164.805185  169.896482  169.943557
# 1   Moderate Uniform  150.020750  159.980243  169.860159  170.339824
# 2       Wide Uniform  130.079200  149.578445  169.635559  169.429876
# 3  Very Wide Uniform  100.089923  134.677043  169.228285  169.100110
# 4    Shifted Uniform  180.037044  189.693657  199.162633  199.437709
#
#            Q3         Max        IQR  Box Width
# 0  175.177868  179.982095  10.372683  10.372683
# 1  180.522134  189.976876  20.541891  20.541891
# 2  189.673514  209.981227  40.095069  40.095069
# 3  204.353148  239.917250  69.676105  69.676105
# 4  209.042664  219.988594  19.349007  19.349007

# %%
run.violin_plot()
# Out:
#              Dataset         Min         Max       Range        Std  \
# 0     Narrow Uniform  160.024661  179.982095   19.957433   5.828797
# 1   Moderate Uniform  150.020750  189.976876   39.956127  11.567918
# 2       Wide Uniform  130.079200  209.981227   79.902027  23.154130
# 3  Very Wide Uniform  100.089923  239.917250  139.827327  40.618334
# 4    Shifted Uniform  180.037044  219.988594   39.951550  11.268794
#
#            Q1          Q3        IQR  Peak Density Value  Peak Densiسty
# 0  164.805185  175.177868  10.372683          163.021273       0.052486
# 1  159.980243  180.522134  20.541891          168.019005       0.026372
# 2  149.578445  189.673514  40.095069          171.029988       0.013150
# 3  134.677043  204.353148  69.676105          140.540471       0.007432
# 4  189.693657  209.042664  19.349007          189.475048       0.028549

# %%
run.cdf_plot()
# Out:
#              Dataset         Min         Max       Range         P10  \
# 0     Narrow Uniform  160.024661  179.982095   19.957433  162.089878
# 1   Moderate Uniform  150.020750  189.976876   39.956127  154.626656
# 2       Wide Uniform  130.079200  209.981227   79.902027  137.518190
# 3  Very Wide Uniform  100.089923  239.917250  139.827327  112.812379
# 4    Shifted Uniform  180.037044  219.988594   39.951550  184.481032
#
#            Q1      Median          Q3         P90  P10-P90 Range
# 0  164.805185  169.896482  175.177868  177.941206      15.851328
# 1  159.980243  169.860159  180.522134  186.421564      31.794908
# 2  149.578445  169.635559  189.673514  201.615853      64.097663
# 3  134.677043  169.228285  204.353148  226.663102     113.850722
# 4  189.693657  199.162633  209.042664  215.118427      30.637395

# %%
run.qq_plot()
# Out:
#              Dataset  Correlation        R²      RMSE  Max Absolute Deviation  \
# 0     Narrow Uniform     0.975449  0.951502  1.283638                8.802222
# 1   Moderate Uniform     0.976427  0.953409  2.496930               17.554378
# 2       Wide Uniform     0.977683  0.955864  4.864368               35.186770
# 3  Very Wide Uniform     0.976656  0.953857  8.725172               61.610466
# 4    Shifted Uniform     0.979216  0.958864  2.285538               16.932566
#
#          Mean        Std
# 0  169.943557   5.828797
# 1  170.339824  11.567918
# 2  169.429876  23.154130
# 3  169.100110  40.618334
# 4  199.437709  11.268794

# %%
run.mean_std_plot()
# Out:
#              Dataset        Mean        Std  Mean - Std  Mean + Std
# 0     Narrow Uniform  169.943557   5.831714  164.111843  175.775271
# 1   Moderate Uniform  170.339824  11.573706  158.766118  181.913530
# 2       Wide Uniform  169.429876  23.165716  146.264160  192.595591
# 3  Very Wide Uniform  169.100110  40.638659  128.461451  209.738769
# 4    Shifted Uniform  199.437709  11.274433  188.163276  210.712142
