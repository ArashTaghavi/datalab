# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import MissingValueDistributionDataset

# %%
run = NumericalContinuous(MissingValueDistributionDataset())

# %%
run.distribution()
# Out:
#                    Dataset         Min         Max        Mean       Std  \
# 0        No Missing Values  140.812697  195.430829  169.768868  7.913737
# 1       Few Missing Values  140.812697  195.430829  169.759541  7.922498
# 2  Moderate Missing Values  146.283769  195.430829  169.649149  7.898129
# 3      Many Missing Values  149.466732  193.310900  169.894991  7.679473
# 4   Extreme Missing Values  154.391718  187.133181  169.597843  6.213418
#
#    Percentage Within ±5 of Mean
# 0                          48.9
# 1                          49.0
# 2                          43.6
# 3                          24.5
# 4                           5.4

# %%
run.box_plot()
# Out:
#                    Dataset         Min          Q1      Median        Mean  \
# 0        No Missing Values  140.812697  164.429497  170.049423  169.768868
# 1       Few Missing Values  140.812697  164.420609  170.000675  169.759541
# 2  Moderate Missing Values  146.283769  164.240003  169.784619  169.649149
# 3      Many Missing Values  149.466732  164.664661  170.025694  169.894991
# 4   Extreme Missing Values  154.391718  165.648788  169.982772  169.597843
#
#            Q3         Max        IQR  Box Width
# 0  174.719094  195.430829  10.289597  10.289597
# 1  174.716375  195.430829  10.295766  10.295766
# 2  174.668376  195.430829  10.428374  10.428374
# 3  174.699147  193.310900  10.034485  10.034485
# 4  174.280164  187.133181   8.631376   8.631376

# %%
run.violin_plot()
# Out:
#                    Dataset         Min         Max      Range       Std  \
# 0        No Missing Values  140.812697  195.430829  54.618132  7.909779
# 1       Few Missing Values  140.812697  195.430829  54.618132  7.918524
# 2  Moderate Missing Values  146.283769  195.430829  49.147060  7.893740
# 3      Many Missing Values  149.466732  193.310900  43.844167  7.671790
# 4   Extreme Missing Values  154.391718  187.133181  32.741462  6.182273
#
#            Q1          Q3        IQR  Peak Density Value  Peak Densiسty
# 0  164.429497  174.719094  10.289597          171.429468       0.052158
# 1  164.420609  174.716375  10.295766          171.429468       0.051906
# 2  164.240003  174.668376  10.428374          171.177075       0.051085
# 3  164.664661  174.699147  10.034485          171.103544       0.051872
# 4  165.648788  174.280164   8.631376          173.400776       0.056941

# %%
run.cdf_plot()
# Out:
#                    Dataset         Min         Max      Range         P10  \
# 0        No Missing Values  140.812697  195.430829  54.618132  159.735092
# 1       Few Missing Values  140.812697  195.430829  54.618132  159.723601
# 2  Moderate Missing Values  146.283769  195.430829  49.147060  159.623656
# 3      Many Missing Values  149.466732  193.310900  43.844167  159.967591
# 4   Extreme Missing Values  154.391718  187.133181  32.741462  161.605485
#
#            Q1      Median          Q3         P90  P10-P90 Range
# 0  164.429497  170.049423  174.719094  180.031978      20.296885
# 1  164.420609  170.000675  174.716375  180.086511      20.362910
# 2  164.240003  169.784619  174.668376  179.984972      20.361316
# 3  164.664661  170.025694  174.699147  179.660179      19.692588
# 4  165.648788  169.982772  174.280164  176.874569      15.269085

# %%
run.qq_plot()
# Out:
#                    Dataset  Correlation        R²      RMSE  \
# 0        No Missing Values     0.999381  0.998763  0.278175
# 1       Few Missing Values     0.999399  0.998799  0.274448
# 2  Moderate Missing Values     0.999405  0.998810  0.272253
# 3      Many Missing Values     0.998909  0.997819  0.358295
# 4   Extreme Missing Values     0.993482  0.987007  0.704692
#
#    Max Absolute Deviation        Mean       Std
# 0                2.927999  169.768868  7.909779
# 1                2.896074  169.759541  7.918524
# 2                2.377551  169.649149  7.893740
# 3                3.284168  169.894991  7.671790
# 4                1.932688  169.597843  6.182273

# %%
run.mean_std_plot()
# Out:
#                    Dataset        Mean       Std  Mean - Std  Mean + Std
# 0        No Missing Values  169.768868  7.913737  161.855131  177.682604
# 1       Few Missing Values  169.759541  7.922498  161.837042  177.682039
# 2  Moderate Missing Values  169.649149  7.898129  161.751020  177.547279
# 3      Many Missing Values  169.894991  7.679473  162.215518  177.574464
# 4   Extreme Missing Values  169.597843  6.213418  163.384425  175.811261
