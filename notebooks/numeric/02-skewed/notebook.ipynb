# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import SkewedDistributionDataset

# %%
run = NumericalContinuous(SkewedDistributionDataset())

# %%
run.distribution()

# %%
run.box_plot()
# Out:
#                  Dataset         Min          Q1      Median        Mean  \
# 0        Mild Right Skew  140.812697  164.429497  170.064250  170.672533
# 1    Moderate Right Skew  140.812697  164.429497  170.084019  171.877420
# 2      Strong Right Skew  140.812697  164.429497  170.108731  173.383529
# 3     Extreme Right Skew  140.812697  164.429497  170.148269  175.793303
# 4  Right Skew + Outliers  140.812697  164.568554  170.159830  172.224363
#
#            Q3         Max        IQR  Box Width
# 0  176.134822  203.060078  11.705325  11.705325
# 1  178.022460  213.232410  13.592963  13.592963
# 2  180.382007  225.947825  15.952510  15.952510
# 3  184.157282  246.292488  19.727785  19.727785
# 4  178.396687  260.000000  13.828132  13.828132

# %%
run.violin_plot()
# Out:
#                  Dataset         Min         Max       Range        Std  \
# 0        Mild Right Skew  140.812697  203.060078   62.247381   9.079351
# 1    Moderate Right Skew  140.812697  213.232410   72.419713  10.705721
# 2      Strong Right Skew  140.812697  225.947825   85.135127  12.805099
# 3     Extreme Right Skew  140.812697  246.292488  105.479791  16.249841
# 4  Right Skew + Outliers  140.812697  260.000000  119.187303  11.585452
#
#            Q1          Q3        IQR  Peak Density Value  Peak Densiسty
# 0  164.429497  176.134822  11.705325          168.852058       0.045238
# 1  164.429497  178.022460  13.592963          167.852290       0.041520
# 2  164.429497  180.382007  15.952510          167.145785       0.038448
# 3  164.429497  184.157282  19.727785          166.364358       0.034693
# 4  164.568554  178.396687  13.828132          167.895298       0.040819

# %%
run.cdf_plot()
# Out:
#                  Dataset         Min         Max       Range         P10  \
# 0        Mild Right Skew  140.812697  203.060078   62.247381  159.735092
# 1    Moderate Right Skew  140.812697  213.232410   72.419713  159.735092
# 2      Strong Right Skew  140.812697  225.947825   85.135127  159.735092
# 3     Extreme Right Skew  140.812697  246.292488  105.479791  159.735092
# 4  Right Skew + Outliers  140.812697  260.000000  119.187303  159.760290
#
#            Q1      Median          Q3         P90  P10-P90 Range
# 0  164.429497  170.064250  176.134822  183.041571      23.306479
# 1  164.429497  170.084019  178.022460  187.054362      27.319270
# 2  164.429497  170.108731  180.382007  192.070351      32.335259
# 3  164.429497  170.148269  184.157282  200.095934      40.360841
# 4  164.568554  170.159830  178.396687  187.766450      28.006161

# %%
run.qq_plot()
# Out:
#                  Dataset  Correlation        R²      RMSE  \
# 0        Mild Right Skew     0.997171  0.994350  0.682448
# 1    Moderate Right Skew     0.988759  0.977644  1.600720
# 2      Strong Right Skew     0.976174  0.952916  2.778546
# 3     Extreme Right Skew     0.957759  0.917302  4.673021
# 4  Right Skew + Outliers     0.967094  0.935271  2.947560
#
#    Max Absolute Deviation        Mean        Std
# 0                4.109673  170.672533   9.079351
# 1                7.898646  171.877420  10.705721
# 2               12.634862  173.383529  12.805099
# 3               20.212808  175.793303  16.249841
# 4               50.883843  172.224363  11.585452

# %%
run.mean_std_plot()
# Out:
#                  Dataset        Mean        Std  Mean - Std  Mean + Std
# 0        Mild Right Skew  170.672533   9.083894  161.588639  179.756427
# 1    Moderate Right Skew  171.877420  10.711078  161.166342  182.588498
# 2      Strong Right Skew  173.383529  12.811506  160.572022  186.195035
# 3     Extreme Right Skew  175.793303  16.257972  159.535330  192.051275
# 4  Right Skew + Outliers  172.224363  11.591249  160.633114  183.815612
