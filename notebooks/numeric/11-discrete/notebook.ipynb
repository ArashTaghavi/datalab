# %%
from datalab.numerical import NumericalDiscrete
from datalab.numerical.discrete.dataset import DiscreteDistributionDataset

# %%
run = NumericalDiscrete(DiscreteDistributionDataset())

# %%
run.histogram()
# Out:
#                 Dataset  Min  Max  Range  Unique Values     Mean  Median  \
# 0     Few Unique Values    1    5      4              5    3.011     3.0
# 1    Many Unique Values    1   20     19             20   10.438    10.0
# 2  Imbalanced Frequency    1    5      4              5    1.784     1.0
# 3        Shifted Values  101  120     19             20  110.270   110.0
#
#         Std  Most Frequent Value  Max Frequency  Most Frequent %
# 0  1.416644                    3            220             22.0
# 1  5.821697                    7             58              5.8
# 2  1.057045                    1            549             54.9
# 3  5.835503                  107             66              6.6

# %%
run.dot_plot()

# %%
run.frequency_plot()
