# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import InfiniteDistributionDataset

# %%
run = NumericalContinuous(InfiniteDistributionDataset())

# %%
run.distribution()
# Out:
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/pandas/core/nanops.py:1028: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                                Dataset         Min         Max        Mean  \
# 0                   No Infinite Values  140.812697  195.430829  169.768868
# 1         Few Positive Infinite Values  140.812697         inf         inf
# 2         Few Negative Infinite Values        -inf  195.430829        -inf
# 3  Positive + Negative Infinite Values        -inf         inf         NaN
# 4                 Many Infinite Values        -inf         inf         NaN
#
#         Std  Percentage Within ±5 of Mean
# 0  7.913737                          48.9
# ...

# %%
run.box_plot()
# Out:
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#                                Dataset         Min          Q1      Median  \
# 0                   No Infinite Values  140.812697  164.429497  170.049423
# 1         Few Positive Infinite Values  140.812697  164.429497  170.049423
# 2         Few Negative Infinite Values        -inf  164.357431  169.971833
# 3  Positive + Negative Infinite Values        -inf  164.397071  169.992658
# 4                 Many Infinite Values        -inf  164.220200  169.902384
#
#          Mean          Q3         Max        IQR  Box Width
# 0  169.768868  174.719094  195.430829  10.289597  10.289597
# 1         inf  174.883082         inf  10.453586  10.453586
# 2        -inf  174.702649  195.430829  10.345217  10.345217
# 3         NaN  174.719094         inf  10.322023  10.322023
# ...

# %%
run.violin_plot()
# Out:
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/lib/_function_base_impl.py:2895: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run.violin_plot()
#
# File ~/Documents/datalab/src/datalab/numerical/continuous/numerical_continuous.py:36, in NumericalContinuous.violin_plot(self)
#      31 def violin_plot(self):
#      32     ViolinPlot(columns=self.columns, titles=self.titles).draw()
#      34     return NormalViolinPlotStatistics(
#      35         columns=self.columns, titles=self.titles
# ---> 36     ).statistics()
#
# File ~/Documents/datalab/src/datalab/numerical/continuous/statistics/normal_violin_plot_statistics.py:19, in NormalViolinPlotStatistics.statistics(self)
#      15 for column, title in zip(self.columns, self.titles):
# ...

# %%
run.cdf_plot()
# Out:
#                                Dataset         Min         Max      Range  \
# 0                   No Infinite Values  140.812697  195.430829  54.618132
# 1         Few Positive Infinite Values  140.812697         inf        inf
# 2         Few Negative Infinite Values        -inf  195.430829        inf
# 3  Positive + Negative Infinite Values        -inf         inf        inf
# 4                 Many Infinite Values        -inf         inf        inf
#
#           P10          Q1      Median          Q3         P90  P10-P90 Range
# 0  159.735092  164.429497  170.049423  174.719094  180.031978      20.296885
# 1  159.735092  164.429497  170.049423  174.883082  180.394479      20.659387
# 2  159.582186  164.357431  169.971833  174.702649  180.031978      20.449792
# 3  159.623656  164.397071  169.992658  174.719094  180.308167      20.684511
# 4  159.244545  164.220200  169.902384  174.883082  180.570913      21.326367

# %%
run.qq_plot()
# Out:
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/scipy/stats/_stats_py.py:1172: RuntimeWarning: invalid value encountered in subtract
#   a_zero_mean = a - mean
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/scipy/stats/_stats_py.py:10927: RuntimeWarning: invalid value encountered in vecdot
#   ssxym = xp.vecdot(x_, y_, axis=-1) / n
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:132: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/lib/_function_base_impl.py:2895: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/lib/_function_base_impl.py:2900: RuntimeWarning: invalid value encountered in dot
#   c = dot(X, X_T.conj())
# ...

# %%
run.mean_std_plot()
# Out:
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/pandas/core/nanops.py:1028: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/numpy/_core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/user/Documents/datalab/.venv/lib/python3.14/site-packages/pandas/core/nanops.py:1028: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                                Dataset        Mean       Std  Mean - Std  \
# 0                   No Infinite Values  169.768868  7.913737  161.855131
# ...
