# %%
from datalab.numerical import NumericalContinuous
from datalab.numerical.continuous.dataset import NormalDistributionDataset

# %%
run = NumericalContinuous(dataset=NormalDistributionDataset())

# %%
# run.distribution()

# %%
# run.box_plot()

# %%
# run.violin_plot()

# %%
# run.cdf_plot()

# %%
# run.qq_plot()

# %%
# run.mean_std_plot()
