# %%
from datalab.categorical import CategoricalNominal
from datalab.categorical.nominal.dataset import CategoricalNominalDataset

# %%
run = CategoricalNominal(dataset=CategoricalNominalDataset())

# %%
run.cardinality_plot()

# %%
run.count_plot()

# %%
run.cumulative_frequency_plot()

# %%
run.entropy_plot()

# %%
run.frequency_plot()

# %%
run.length_plot()

# %%
run.missing_value_plot()

# %%
run.pareto_plot()

# %%
run.pie_plot()

# %%
run.rare_category_plot()

# %%
run.top_category_plot()

# %%
run.treemap_plot()
